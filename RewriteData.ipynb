# %%
import json

# %%
f = open('data.json')
data = json.load(f)
data = data[0]
print(data)
# Out:
# {'special-prize': '40169', 'prize1': '74085', 'prize2_item0': '03024 ', 'prize2_item1': ' 33253', 'prize3_item0': '95499 ', 'prize3_item1': ' 49160 ', 'prize3_item2': ' 46104 ', 'prize3_item3': ' 99338 ', 'prize3_item4': ' 97510 ', 'prize3_item5': ' 25548', 'prize4_item0': '1963 ', 'prize4_item1': ' 2870 ', 'prize4_item2': ' 8793 ', 'prize4_item3': ' 7261', 'prize5_item0': '9763 ', 'prize5_item1': ' 6916 ', 'prize5_item2': ' 4588 ', 'prize5_item3': ' 0608 ', 'prize5_item4': ' 9073 ', 'prize5_item5': ' 8742', 'prize6_item0': '867 ', 'prize6_item1': ' 115 ', 'prize6_item2': ' 321', 'prize7_item0': '76 ', 'prize7_item1': ' 56 ', 'prize7_item2': ' 98 ', 'prize7_item3': ' 90'}

# %%
data1 = {}
for token in data:
    data1[token] = []
    data1[token].append(data[token])
print(data1)
with open('data.json', 'w') as outfile:
    json.dump(data1, outfile)
# Out:
# {'special-prize': ['40169'], 'prize1': ['74085'], 'prize2_item0': ['03024 '], 'prize2_item1': [' 33253'], 'prize3_item0': ['95499 '], 'prize3_item1': [' 49160 '], 'prize3_item2': [' 46104 '], 'prize3_item3': [' 99338 '], 'prize3_item4': [' 97510 '], 'prize3_item5': [' 25548'], 'prize4_item0': ['1963 '], 'prize4_item1': [' 2870 '], 'prize4_item2': [' 8793 '], 'prize4_item3': [' 7261'], 'prize5_item0': ['9763 '], 'prize5_item1': [' 6916 '], 'prize5_item2': [' 4588 '], 'prize5_item3': [' 0608 '], 'prize5_item4': [' 9073 '], 'prize5_item5': [' 8742'], 'prize6_item0': ['867 '], 'prize6_item1': [' 115 '], 'prize6_item2': [' 321'], 'prize7_item0': ['76 '], 'prize7_item1': [' 56 '], 'prize7_item2': [' 98 '], 'prize7_item3': [' 90']}
